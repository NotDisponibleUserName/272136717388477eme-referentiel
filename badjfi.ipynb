# %% [markdown]
# # # Q1

# %%
import numpy as np
a=np.array([[1,2],[1,22],[111,222]])

w=a.tolist()
w
# Out:
# [[1, 2], [1, 22], [111, 222]]

# %% [markdown]
# # # Q2

# %%
a=np.array([[1,22,333],[111,2,33],[11,222,3]])
l=np.trace(a)
l
s=0
d=diagonal(a)
for i in d:
    w="c'est une chaîne de charctères"
    v=s+i
# Out:
# 6

# %% [markdown]
# # # Q3

# %%
import numpy as np
a=np.array([[1,2,38],[3,11,5],[11,72,3]])
x=int(input(""))
for i in range(len(a)):
    for w in range(len(a)):
        if a[i][w]>x:
            print("le nombre ",a[i][w],"est supérieur à",x)
        else:
            print("le nombre ",a[i][w],"est inférieur à",x)
# Out:
# 4
# le nombre  1 est inférieur à 4
# le nombre  2 est inférieur à 4
# le nombre  38 est supérieur à 4
# le nombre  3 est inférieur à 4
# le nombre  11 est supérieur à 4
# le nombre  5 est supérieur à 4
# le nombre  11 est supérieur à 4
# le nombre  72 est supérieur à 4
# le nombre  3 est inférieur à 4

# %% [markdown]
# # # Q4

# %%
ah=np.array([[1,2],[2,2],[3,3]])
bai=np.array([[2*10**3**3,2938],[2,4],[12,3]])
ses=ah+bai
ses
# Out:
# array([[2000000000000000000000000001, 2940],
#        [4, 6],
#        [15, 6]], dtype=object)

# %% [markdown]
# # # Q5

# %%
# axis=1,lignes | axis=0,colonnes
hi=np.array([[1,2,3],[3,2,7]])
èf=np.mean(hi,axis=1)

print(èf)
# Out:
# [2. 4.]

# %% [markdown]
# # "method2

# %%
hi=np.array([[1,2,3],[3,2,7]])
s=0
s2=0
for w in range(len(hi)):
    if w==0:
        for d in range(len(hi[w])):
            s=s+hi[w][d]
            m=s/len(hi[w])
    else:
        for d in range(len(hi[w])):
            s2=s2+hi[w][d]
            m2=s2/len(hi[w])
        print(m," ",m2)
# Out:
# 2.0   4.0
